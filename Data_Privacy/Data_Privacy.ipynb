# %% [markdown]
# # Data Privacy

# %%
from flwr.client.mod import adaptiveclipping_mod
from flwr.server.strategy import (
    DifferentialPrivacyClientSideAdaptiveClipping,
    FedAvg)
from flwr.client import Client, ClientApp, NumPyClient
from flwr.server import ServerApp, ServerConfig
from flwr.simulation import run_simulation
from utils import *

# %% [markdown]
# #### Load the MNIST dataset
#
# * Use `flwr-datasets` that provides with a Federated Dataset abstraction.

# %%
def load_data(partition_id):
    fds = FederatedDataset(dataset="mnist", partitioners={"train": 10})
    partition = fds.load_partition(partition_id)

    traintest = partition.train_test_split(test_size=0.2, seed=42)
    traintest = traintest.with_transform(normalize)
    trainset, testset = traintest["train"], traintest["test"]

    trainloader = DataLoader(trainset, batch_size=64, shuffle=True)
    testloader = DataLoader(testset, batch_size=64)
    return trainloader, testloader

# %% [markdown]
# #### Define the Model
#
# * Define the FlowerClient.

# %%
class FlowerClient(NumPyClient):
    def __init__(self, net, trainloader, testloader):
        self.net = net
        self.trainloader = trainloader
        self.testloader = testloader

    def fit(self, parameters, config):
        set_weights(self.net, parameters)
        train_model(self.net, self.trainloader)
        return get_weights(self.net), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        set_weights(self.net, parameters)
        loss, accuracy = evaluate_model(self.net, self.testloader)
        return loss, len(self.testloader), {"accuracy": accuracy}


def client_fn(context: Context) -> Client:
    net = SimpleModel()
    partition_id = int(context.node_config["partition-id"])
    trainloader, testloader = load_data(partition_id=partition_id)
    return FlowerClient(net, trainloader, testloader).to_client()

# %% [markdown]
# * Define the ClientApp.

# %%
client = ClientApp(
    client_fn,
    mods=[adaptiveclipping_mod],
)

# %% [markdown]
# * Define the Server side with the strategy FedAvg.
#
# **DP:** Differential Privacy.

# %%
net = SimpleModel()
params = ndarrays_to_parameters(get_weights(net))

def server_fn(context: Context):
    fedavg_without_dp = FedAvg(
        fraction_fit=0.6,
        fraction_evaluate=1.0,
        initial_parameters=params,
    )
    fedavg_with_dp = DifferentialPrivacyClientSideAdaptiveClipping(
        fedavg_without_dp,  # <- wrap the FedAvg strategy
        noise_multiplier=0.3,
        num_sampled_clients=6,
    )
    
    config = ServerConfig(num_rounds=50)
    
    return ServerAppComponents(
        strategy=fedavg_with_dp,
        config=config,
    )

# %%
server = ServerApp(server_fn=server_fn)

# %% [markdown]
# * Run Client and Server apps.

# %%
run_simulation(server_app=server,
               client_app=client,
               num_supernodes=10,
               backend_config=backend_setup
               )
# Out:
# INFO : Starting Flower ServerApp, config: num_rounds=50, no round_timeout
# INFO :
# INFO : [INIT]
# INFO : Using initial global parameters provided by strategy
# INFO : Evaluating initial global parameters
# INFO :
# INFO : [ROUND 1]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.1000.
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.1000. [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0052 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 2]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0898. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0898. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0047 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 3]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0817. [repeated 4x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0817. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0043 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 4]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0737. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0737. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0039 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 5]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0671. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0671. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0035 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 6]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0602. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0602. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0031 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 7]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0543. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0543. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0029 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 8]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0495. [repeated 4x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0495. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0026 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 9]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0447. [repeated 4x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0447. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0023 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 10]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0405. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0405. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0021 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 11]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0365. [repeated 4x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0365. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0019 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 12]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0332. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0332. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0018 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 13]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0304. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0304. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0016 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 14]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0277. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0277. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0014 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 15]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0249. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0249. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0013 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 16]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0223. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0223. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0012 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 17]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0202. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0202. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0011 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 18]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0184. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0184. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0009 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 19]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0164. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0164. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0009 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 20]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0149. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0149. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0008 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 21]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0137. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0137. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0007 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 22]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0124. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0124. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0006 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 23]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0111. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0111. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0111. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0006 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 24]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0100. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0100. [repeated 3x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0005 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 25]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0090. [repeated 3x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0090. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0005 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 26]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0081. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0081. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0004 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 27]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0073. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0073. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0004 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 28]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0066. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0066. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0003 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 29]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) OMP: Warning #191: Forking a process while a parallel region is active is potentially unsafe.
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0066.
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0060.
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0060. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0003 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 30]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0055. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0055. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0003 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 31]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0049. [repeated 4x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0049. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0003 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 32]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0045. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0045. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0002 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 33]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0041. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0041. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0002 stdev added
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0041. [repeated 3x across cluster]INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
#
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 34]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0037.
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0037.
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0037.
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0037.
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0037.
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0037.
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0002 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 35]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0033.
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0033.
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0033.
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0033.
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0033. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0002 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 36]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0030.
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0030.
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0030. [repeated 3x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0002 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 37]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0027. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0027. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0027. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 38]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0024. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0024. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 39]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0022. [repeated 4x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0022. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0022. [repeated 2x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 40]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0020. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0020. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 41]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0019. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0019. [repeated 3x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 42]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0017. [repeated 3x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0017. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 43]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0015. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0015. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 44]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0013. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0013. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 45]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0012. [repeated 2x across cluster]
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0012. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 46]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0011. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0011. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 47]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0010. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0010. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0001 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 48]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0009. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0009. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0000 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 49]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0008. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0008. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0000 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 50]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0007. [repeated 2x across cluster]
# (ClientAppActor pid=65634) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0007. [repeated 4x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0000 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [SUMMARY]
# INFO : Run finished 50 round(s) in 1285.98s
# INFO : 	History (loss, distributed):
# INFO : 		round 1: 42.449600625038144
# INFO : 		round 2: 41.370535945892335
# INFO : 		round 3: 40.429740118980405
# INFO : 		round 4: 39.61834394931793
# INFO : 		round 5: 38.79365574121475
# INFO : 		round 6: 38.07104903459549
# INFO : 		round 7: 37.40941954851151
# INFO : 		round 8: 36.71946446895599
# INFO : 		round 9: 36.20773185491562
# INFO : 		round 10: 35.61855973005295
# INFO : 		round 11: 35.138192367553714
# INFO : 		round 12: 34.53537238836289
# INFO : 		round 13: 34.119759273529056
# INFO : 		round 14: 33.736918079853055
# INFO : 		round 15: 33.42102872133255
# INFO : 		round 16: 33.090192115306856
# INFO : 		round 17: 32.77650489807129
# INFO : 		round 18: 32.53322159051895
# INFO : 		round 19: 32.31425094604492
# INFO : 		round 20: 32.07148007154465
# INFO : 		round 21: 31.874346435070038
# INFO : 		round 22: 31.673607671260832
# INFO : 		round 23: 31.51943814754486
# INFO : 		round 24: 31.382094585895537
# INFO : 		round 25: 31.253489196300507
# INFO : 		round 26: 31.12593894004822
# INFO : 		round 27: 31.011483466625215
# INFO : 		round 28: 30.920646584033967
# INFO : 		round 29: 30.83222941160202
# INFO : 		round 30: 30.750940835475923
# INFO : 		round 31: 30.6796959400177
# INFO : 		round 32: 30.630211794376372
# INFO : 		round 33: 30.571921753883363
# INFO : 		round 34: 30.52180688381195
# INFO : 		round 35: 30.47328896522522
# INFO : 		round 36: 30.42709251642227
# INFO : 		round 37: 30.38339009284973
# INFO : 		round 38: 30.34513738155365
# INFO : 		round 39: 30.313755464553832
# INFO : 		round 40: 30.289299738407134
# INFO : 		round 41: 30.26344816684723
# INFO : 		round 42: 30.239607059955596
# INFO : 		round 43: 30.220263493061065
# INFO : 		round 44: 30.201635587215424
# INFO : 		round 45: 30.183155715465546
# INFO : 		round 46: 30.16812958717346
# INFO : 		round 47: 30.15289385318756
# INFO : 		round 48: 30.14177337884903
# INFO : 		round 49: 30.1335067987442
# INFO : 		round 50: 30.124373984336852
# INFO :
# (ClientAppActor pid=65633) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0007.
